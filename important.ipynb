# %%
from collections import defaultdict
def fg(nums):
    hash={}
    groups=defaultdict(list)
    for i in nums:
        key="".join(sorted(i))
        if key in hash:
            hash[key].append(i)
        else:
            hash[key]=[]
            hash[key].append(i)
            
    return hash
a=["cat","act","tac","tea","eat"]
print(fg(a))
#hum defaulddict me list bana ke use kar sakte hai nahi to hum key ko ek list par point kar sakte hai jiske andar data append kar skate hai
# Out:
# hello world
